# %%
import torch
import cv2
import os
import xml.etree.ElementTree as ET
import numpy as np
import yaml
from xml.dom import minidom

# %%
homography_matrix_file = "homography_matrix.txt"
narrow_cam_details_file = "narrow_cam_details.txt"
# xml_root_path = "D:\ACA\\fyp\\codes\\bbox_concatenate\\278\\Annotations"
xml_root_path = "D:\\ACA\\fyp\\codes\\bbox_concatenate\\xml_files\\test_1"
torch_output_xml_folder = xml_root_path+"\\concat_torch"
numpy_output_xml_folder = xml_root_path+"\\concat_2"
# numpy_output_xml_folder = xml_root_path+"\\concat_numpy"

# %%
def get_all_class_names(class_names_file):
    with open(class_names_file) as f:
        data = yaml.safe_load(f)
        class_names = data["names"]
        print(class_names)
    return class_names

class_names = get_all_class_names('class_names.yaml')
# Out:
# ['Green', 'Green-up', 'Green-left', 'Green-right', 'Red', 'Yellow', 'Red-Yellow', 'Count-down', 'Empty', 'Empty-count-down']

# %%
wide_cam_file_names = os.listdir(os.path.join(xml_root_path,"wide"))
narrow_cam_file_names = os.listdir(os.path.join(xml_root_path,"narrow"))

wide_cam_file_names.sort()
narrow_cam_file_names.sort()

wide_cam_files = [os.path.join(xml_root_path,"wide",i) for i in wide_cam_file_names]
narrow_cam_files = [os.path.join(xml_root_path,"narrow",i) for i in narrow_cam_file_names]

# %%
def get_xml_file_details(xml_file):
    tree = ET.parse(xml_file)
    root = tree.getroot()

    folder = root.find("folder").text
    filename = root.find("filename").text

    return {"folder":folder,"filename":filename}

# %%
def get_bbox_data(xml_file):

    tree = ET.parse(xml_file)
    root = tree.getroot()

    all_bbox_data = []
    for child in root.findall(".//object"):
        bbox_data = [0,0,0,0,0] ## [xmin,ymin,xmax,ymax,class]
        for grandChild in child:
            if(grandChild.tag == 'bndbox'):
                    for coord in grandChild:
                        if(coord.tag == 'xmin'):
                            xmin = float(coord.text)
                            bbox_data[0]=xmin
                            continue
                        elif(coord.tag == 'ymin'): 
                            ymin = float(coord.text)
                            bbox_data[1] = ymin
                            continue
                        elif(coord.tag == 'xmax'): 
                            xmax = float(coord.text)
                            bbox_data[2] = xmax
                            continue
                        elif(coord.tag == 'ymax'): 
                            ymax = float(coord.text)
                            bbox_data[3] = ymax
                            continue
            if (grandChild.tag == 'name'):
                name = grandChild.text
                bbox_data[4] = class_names.index(name)
                continue

        all_bbox_data.append(bbox_data)

    all_bbox_data = np.array(all_bbox_data)

    return all_bbox_data

# %% [markdown]
# ### numpy concatenation

# %%
def check_position(boxes, narrow_region):
        [topx,topy,botx,boty] = narrow_region
        keep = (boxes[:, 0]>topx) & (boxes[:, 1]>topy) & (boxes[:, 2]<botx) & (boxes[:, 3]<boty)
        return keep

def upcast(t):
        T = torch.from_numpy(t)  ## do not know an easy method to find this in numpy
        if T.is_floating_point():
            return t if t.dtype in (np.float32, np.float64) else t.float()
        else:
            return t if t.dtype in (np.int32, np.int64) else t.int()

def box_area(boxes):
        boxes = upcast(boxes)
        return (boxes[:, 2] - boxes[:, 0]) * (boxes[:, 3] - boxes[:, 1])

def box_inter_union(boxes1, boxes2):
        area1 = box_area(boxes1)
        area2 = box_area(boxes2)

        lt = np.maximum(boxes1[:, None, :2], boxes2[:, :2])  # [N,M,2]
        rb = np.minimum(boxes1[:, None, 2:], boxes2[:, 2:])  # [N,M,2]

        wh = upcast(rb - lt).clip(min=0)  # [N,M,2]
        inter = wh[:, :, 0] * wh[:, :, 1]  # [N,M]

        union = area1[:, None] + area2 - inter

        return inter, union

def box_iou(boxes1, boxes2):
        inter, union = box_inter_union(boxes1, boxes2)
        iou = (inter / union)>0.5
        return iou

def clip_boxes_to_box(boxes,narrow_region):
        """
        Clip boxes so that they lie inside an image of size `size`.

        Args:
            boxes (Tensor[N, 4]): boxes in ``(x1, y1, x2, y2)`` format
                with ``0 <= x1 < x2`` and ``0 <= y1 < y2``.
            size (Tuple[height, width]): size of the image

        Returns:
            Tensor[N, 4]: clipped boxes
        """
        [topx,topy,botx,boty] = narrow_region

        dim = boxes.ndim
        boxes_x = boxes[..., 0::2]
        boxes_y = boxes[..., 1::2]

        boxes_x = boxes_x.clip(min=topx, max=botx)
        boxes_y = boxes_y.clip(min=topy, max=boty)

        clipped_boxes = np.stack((boxes_x, boxes_y), axis=dim)
        return clipped_boxes.reshape(boxes.shape)

# %%
# det = reversed(wide_bbox_data)
# narrow_det = reversed(narrow_bbox_data)
def concatenate_bboxes(narrow_bbox_data,wide_bbox_data,narrow_region):

        if (len(narrow_bbox_data)>0 and (len(wide_bbox_data)>0)):
                keep = np.logical_not(check_position(wide_bbox_data[:,:4],narrow_region))
                wide_bbox_data = wide_bbox_data[keep]  ## remove all internal bboxes
                wide_bbox_data_old = np.copy(wide_bbox_data) 
                wide_bbox_data[:,:4] = clip_boxes_to_box(wide_bbox_data[:,:4],narrow_region)
                q = box_iou(wide_bbox_data[:,:4], narrow_bbox_data[:,:4])
                narrow_bbox_data = narrow_bbox_data[np.all(np.logical_not(q),0)]
                concat_bbox_data = np.concatenate((wide_bbox_data_old, narrow_bbox_data), 0)
                # keep = torch.logical_not(check_position(wide_bbox_data[:,:4],narrow_region))
                # wide_bbox_data = wide_bbox_data[keep]  ## remove all internal bboxes
                # wide_bbox_data_old = torch.clone(wide_bbox_data) 
                # wide_bbox_data[:,:4] = clip_boxes_to_box(wide_bbox_data[:,:4])
                # q = box_iou(wide_bbox_data[:,:4], narrow_bbox_data[:,:4])
                # narrow_bbox_data = narrow_bbox_data[torch.all(torch.logical_not(q),0)]
                # concat_bbox_data = torch.cat((wide_bbox_data_old, narrow_bbox_data), 0)
        elif (len(wide_bbox_data)>0):
                concat_bbox_data = wide_bbox_data
        elif (len(narrow_bbox_data)>0):
                concat_bbox_data = narrow_bbox_data
        else:
                concat_bbox_data = None
                print("no boxes in both narrow and wide file")
        return concat_bbox_data

# %% [markdown]
# ### torch concatenation

# %%
# def torch_check_position(boxes, narrow_region):
        
#         [topx,topy,botx,boty] = narrow_region
#         keep = (boxes[:, 0]>topx) & (boxes[:, 1]>topy) & (boxes[:, 2]<botx) & (boxes[:, 3]<boty)

#         return keep

# def torch_upcast(t):
#         if t.is_floating_point():
#             return t if t.dtype in (torch.float32, torch.float64) else t.float()
#         else:
#             return t if t.dtype in (torch.int32, torch.int64) else t.int()

# def torch_box_area(boxes):
#         boxes = torch_upcast(boxes)
#         return (boxes[:, 2] - boxes[:, 0]) * (boxes[:, 3] - boxes[:, 1])

# def torch_box_inter_union(boxes1, boxes2):
#         area1 = torch_box_area(boxes1)
#         area2 = torch_box_area(boxes2)

#         lt = torch.max(boxes1[:, None, :2], boxes2[:, :2])  # [N,M,2]
#         rb = torch.min(boxes1[:, None, 2:], boxes2[:, 2:])  # [N,M,2]

#         wh = torch_upcast(rb - lt).clamp(min=0)  # [N,M,2]
#         inter = wh[:, :, 0] * wh[:, :, 1]  # [N,M]

#         union = area1[:, None] + area2 - inter

#         return inter, union

# def torch_box_iou(boxes1, boxes2):

#         inter, union = torch_box_inter_union(boxes1, boxes2)
#         iou = (inter / union)>0.5
#         return iou

# def torch_clip_boxes_to_box(boxes):
#         """
#         Clip boxes so that they lie inside an image of size `size`.

#         Args:
#             boxes (Tensor[N, 4]): boxes in ``(x1, y1, x2, y2)`` format
#                 with ``0 <= x1 < x2`` and ``0 <= y1 < y2``.
#             size (Tuple[height, width]): size of the image

#         Returns:
#             Tensor[N, 4]: clipped boxes
#         """
#         dim = boxes.dim()
#         boxes_x = boxes[..., 0::2]
#         boxes_y = boxes[..., 1::2]

#         boxes_x = boxes_x.clamp(min=707, max=1160)
#         boxes_y = boxes_y.clamp(min=387, max=654)

#         clipped_boxes = torch.stack((boxes_x, boxes_y), dim=dim)
#         return clipped_boxes.reshape(boxes.shape)

# %%
# def torch_concatenate_bboxes(narrow_bbox_data,wide_bbox_data,narrow_region):

#         if (len(narrow_bbox_data)>0 and (len(wide_bbox_data)>0)):
#                 # rev_wide_det = reversed(det)
#                 keep = torch.logical_not(torch_check_position(wide_bbox_data[:,:4],narrow_region))
#                 wide_bbox_data = wide_bbox_data[keep]
#                 wide_bbox_data_old = torch.clone(wide_bbox_data)
#                 wide_bbox_data[:,:4] = torch_clip_boxes_to_box(wide_bbox_data[:,:4])
#                 # rev_narrow_det = reversed(self.narrow_det)
#                 q = torch_box_iou(wide_bbox_data[:,:4], narrow_bbox_data[:,:4])
#                 narrow_bbox_data = narrow_bbox_data[torch.all(torch.logical_not(q),0)]
#                 concat_bbox_data = torch.cat((wide_bbox_data_old, narrow_bbox_data), 0)

#         elif (len(wide_bbox_data)>0):
#                 concat_bbox_data = wide_bbox_data
#         elif (len(narrow_bbox_data)>0):
#                 concat_bbox_data = narrow_bbox_data
#         else:
#                 concat_bbox_data = None
#                 print("no boxes in both narrow and wide file")
#         return concat_bbox_data

# %% [markdown]
# ### narrow bbox transformation

# %%
def transform_narrow_bbox(bbox_coord_vect,camera_mtx_narrow,dist_coff_narrow,homography_matrix):
    w,h = 1920,1080
    narrow_transformed_coord_vect = []
    for bbox_coords in bbox_coord_vect:
        bbox_coords = bbox_coords.reshape(-1,2)
        # print("box_cords",bbox_coords, bbox_coords.shape, bbox_coords.dtype)
        # print("bbox_cords",bbox_coords)

        ## undistort
        newcameramtx_narrow, _ = cv2.getOptimalNewCameraMatrix(camera_mtx_narrow, dist_coff_narrow, (w,h), 1, (w,h))
        narrow_undist_cords =  cv2.undistortPoints(bbox_coords,camera_mtx_narrow,dist_coff_narrow,P=newcameramtx_narrow)

        ## homography transform
        # narrow_undist_cords = narrow_undist_cords.astype(int)
        narrow_undist_cords = np.float32(narrow_undist_cords).reshape(-1,1,2)
        narrow_transformed_cords = cv2.perspectiveTransform(narrow_undist_cords,homography_matrix)
        narrow_transformed_cords = narrow_transformed_cords.reshape(-1)
        narrow_transformed_cords = list(narrow_transformed_cords)
        # print("box_cords_transformed",narrow_transformed_cords)
        narrow_transformed_coord_vect.append(narrow_transformed_cords)

    narrow_transformed_coord_vect = np.array(narrow_transformed_coord_vect)
    # print("box_cords_transformed_vect",narrow_transformed_coord_vect)
    return narrow_transformed_coord_vect

# %%
def find_narrow_region(camera_mtx_narrow,dist_coff_narrow,homography_matrix):
    w,h = 1920,1080
    region = np.array([[0,0],[1920,1080]],dtype=np.float64)
    newcameramtx_narrow, _ = cv2.getOptimalNewCameraMatrix(camera_mtx_narrow, dist_coff_narrow, (w,h), 1, (w,h))
    narrow_undist_region =  cv2.undistortPoints(region,camera_mtx_narrow,dist_coff_narrow,P=newcameramtx_narrow)
    narrow_undist_region = np.float32(narrow_undist_region).reshape(-1,1,2)
    narrow_transformed_region = cv2.perspectiveTransform(narrow_undist_region,homography_matrix)
    narrow_transformed_region = narrow_transformed_region.reshape(-1).astype(int)
    print("narrow_region on wide frame:",narrow_transformed_region)
    return narrow_transformed_region

# %%
def formatter(elem):
    """Return a pretty-printed XML string for the Element.
    """
    rough_string = ET.tostring(elem, 'utf-8')
    reparsed = minidom.parseString(rough_string)
    return reparsed.toprettyxml(indent="    ")

def create_root(file_data, width, height):
    filename = file_data["filename"]
    folder = file_data["folder"]
    root = ET.Element("annotation")
    ET.SubElement(root, "filename").text = "{}".format(filename)
    ET.SubElement(root, "folder").text = "{}".format(folder)
    size = ET.SubElement(root, "size")
    ET.SubElement(size, "width").text = str(width)
    ET.SubElement(size, "height").text = str(height)
    ET.SubElement(size, "depth").text = "3"
    return root


def create_object_annotation(root, voc_labels):
    for voc_label in voc_labels:  ## [xmin,ymin,xmax,ymax,class]
        obj = ET.SubElement(root, "object")
        ET.SubElement(obj, "name").text = class_names[int(voc_label[4])]
        bbox = ET.SubElement(obj, "bndbox")
        ET.SubElement(bbox, "xmin").text = str(voc_label[0])
        ET.SubElement(bbox, "ymin").text = str(voc_label[1])
        ET.SubElement(bbox, "xmax").text = str(voc_label[2])
        ET.SubElement(bbox, "ymax").text = str(voc_label[3])
    return root

def create_xml_file(DESTINATION_DIR, file_prefix, width, height, voc_labels,file_data):
    root = create_root(file_data, width, height)
    root = create_object_annotation(root, voc_labels)
    with open("{}/{}.xml".format(DESTINATION_DIR, file_prefix), "w") as f:

            f.write(formatter(root))
            f.close()

# %% [markdown]
# ### numpy main

# %%
homography_matrix = np.loadtxt(homography_matrix_file, usecols=range(3))
dist_coff_narrow = np.loadtxt(narrow_cam_details_file, dtype=np.float32, skiprows=19,max_rows=1, delimiter=' ')
camera_mtx_narrow = np.loadtxt(narrow_cam_details_file, dtype=np.float32, skiprows=14, max_rows=3, delimiter=' ')

# narrow_region = [707, 387,1160, 654]
narrow_region = find_narrow_region(camera_mtx_narrow,dist_coff_narrow,homography_matrix)

count = 0
for (wide_cam_xml,narrow_cam_xml) in zip(wide_cam_files,narrow_cam_files):
    file_data = get_xml_file_details(wide_cam_xml)
    wide_bbox_data = get_bbox_data(wide_cam_xml)
    narrow_bbox_data = get_bbox_data(narrow_cam_xml)
    # print(count+1)
    # for data in narrow_bbox_data:
    #     print(data)
    if (len(narrow_bbox_data)>0):
        narrow_bbox_data[:,:4] = transform_narrow_bbox(narrow_bbox_data[:,:4],camera_mtx_narrow,dist_coff_narrow,homography_matrix)

    concat_bbox_data = concatenate_bboxes(narrow_bbox_data,wide_bbox_data,narrow_region)
    output_file_prefix = wide_cam_xml[-15:-4]
    print("name",output_file_prefix," wide_count:",len(wide_bbox_data), " narrow_count: ",len(narrow_bbox_data), "concat_count: ",len(concat_bbox_data))
    create_xml_file(DESTINATION_DIR=numpy_output_xml_folder, file_prefix=output_file_prefix, width=1920, height=1080, voc_labels=concat_bbox_data,file_data=file_data)
    count += 1
    # if (count>5):
    #     break

    # break
# Out:
# narrow_region on wide frame: [ 704  402 1162  658]
# name wide_t1_001  wide_count: 0  narrow_count:  3 concat_count:  3
# name wide_t1_002  wide_count: 0  narrow_count:  3 concat_count:  3
# name wide_t1_003  wide_count: 0  narrow_count:  3 concat_count:  3
# name wide_t1_004  wide_count: 0  narrow_count:  4 concat_count:  4
# name wide_t1_005  wide_count: 0  narrow_count:  4 concat_count:  4
# name wide_t1_006  wide_count: 0  narrow_count:  4 concat_count:  4
# name wide_t1_007  wide_count: 4  narrow_count:  0 concat_count:  4
# name wide_t1_008  wide_count: 4  narrow_count:  0 concat_count:  4
# name wide_t1_009  wide_count: 0  narrow_count:  3 concat_count:  3
# name wide_t1_010  wide_count: 0  narrow_count:  4 concat_count:  4
# name wide_t1_011  wide_count: 0  narrow_count:  3 concat_count:  3
# name wide_t1_012  wide_count: 0  narrow_count:  4 concat_count:  4
# name wide_t1_013  wide_count: 0  narrow_count:  4 concat_count:  4
# name wide_t1_014  wide_count: 0  narrow_count:  4 concat_count:  4
# name wide_t1_015  wide_count: 0  narrow_count:  4 concat_count:  4
# name wide_t1_016  wide_count: 0  narrow_count:  4 concat_count:  4
# name wide_t1_017  wide_count: 1  narrow_count:  4 concat_count:  4
# name wide_t1_018  wide_count: 4  narrow_count:  4 concat_count:  4
# name wide_t1_019  wide_count: 4  narrow_count:  6 concat_count:  10
# name wide_t1_020  wide_count: 0  narrow_count:  6 concat_count:  6
# name wide_t1_021  wide_count: 0  narrow_count:  6 concat_count:  6
# name wide_t1_022  wide_count: 0  narrow_count:  3 concat_count:  3
# name wide_t1_023  wide_count: 0  narrow_count:  4 concat_count:  4
# name wide_t1_024  wide_count: 0  narrow_count:  6 concat_count:  6
# name wide_t1_025  wide_count: 0  narrow_count:  6 concat_count:  6
# name wide_t1_026  wide_count: 2  narrow_count:  6 concat_count:  6
# name wide_t1_027  wide_count: 2  narrow_count:  6 concat_count:  6
# name wide_t1_028  wide_count: 3  narrow_count:  6 concat_count:  6
# name wide_t1_029  wide_count: 5  narrow_count:  4 concat_count:  6
# name wide_t1_030  wide_count: 6  narrow_count:  4 concat_count:  6
# name wide_t1_031  wide_count: 4  narrow_count:  0 concat_count:  4
# name wide_t1_032  wide_count: 3  narrow_count:  1 concat_count:  3
# name wide_t1_033  wide_count: 2  narrow_count:  3 concat_count:  3
# name wide_t1_034  wide_count: 3  narrow_count:  3 concat_count:  3
# name wide_t1_035  wide_count: 3  narrow_count:  3 concat_count:  3
# name wide_t1_036  wide_count: 3  narrow_count:  2 concat_count:  3
# name wide_t1_037  wide_count: 2  narrow_count:  0 concat_count:  2
# name wide_t1_038  wide_count: 2  narrow_count:  0 concat_count:  2
# name wide_t1_039  wide_count: 1  narrow_count:  4 concat_count:  4
# name wide_t1_040  wide_count: 0  narrow_count:  4 concat_count:  4
# name wide_t1_041  wide_count: 0  narrow_count:  4 concat_count:  4
# name wide_t1_042  wide_count: 1  narrow_count:  3 concat_count:  3
# name wide_t1_043  wide_count: 3  narrow_count:  4 concat_count:  4
# name wide_t1_044  wide_count: 4  narrow_count:  0 concat_count:  4
# name wide_t1_045  wide_count: 0  narrow_count:  1 concat_count:  1
# name wide_t1_046  wide_count: 1  narrow_count:  1 concat_count:  1
# name wide_t1_047  wide_count: 0  narrow_count:  4 concat_count:  4
# name wide_t1_048  wide_count: 0  narrow_count:  5 concat_count:  5
# name wide_t1_049  wide_count: 0  narrow_count:  5 concat_count:  5
# name wide_t1_050  wide_count: 0  narrow_count:  6 concat_count:  6
# name wide_t1_051  wide_count: 0  narrow_count:  6 concat_count:  6
# name wide_t1_052  wide_count: 1  narrow_count:  6 concat_count:  6
# name wide_t1_053  wide_count: 3  narrow_count:  5 concat_count:  6
# name wide_t1_054  wide_count: 3  narrow_count:  3 concat_count:  6
# name wide_t1_055  wide_count: 2  narrow_count:  3 concat_count:  5
# name wide_t1_056  wide_count: 0  narrow_count:  3 concat_count:  3
# name wide_t1_057  wide_count: 0  narrow_count:  3 concat_count:  3
# name wide_t1_058  wide_count: 0  narrow_count:  3 concat_count:  3
# name wide_t1_059  wide_count: 0  narrow_count:  3 concat_count:  3
# name wide_t1_060  wide_count: 0  narrow_count:  3 concat_count:  3
# name wide_t1_061  wide_count: 0  narrow_count:  3 concat_count:  3
# name wide_t1_062  wide_count: 0  narrow_count:  3 concat_count:  3
# name wide_t1_063  wide_count: 0  narrow_count:  3 concat_count:  3
# name wide_t1_064  wide_count: 0  narrow_count:  3 concat_count:  3
# name wide_t1_065  wide_count: 0  narrow_count:  3 concat_count:  3
# name wide_t1_066  wide_count: 0  narrow_count:  3 concat_count:  3
# name wide_t1_067  wide_count: 0  narrow_count:  3 concat_count:  3
# name wide_t1_068  wide_count: 0  narrow_count:  3 concat_count:  3
# name wide_t1_069  wide_count: 0  narrow_count:  3 concat_count:  3
# name wide_t1_070  wide_count: 0  narrow_count:  3 concat_count:  3
# name wide_t1_071  wide_count: 3  narrow_count:  0 concat_count:  3
# name wide_t1_072  wide_count: 3  narrow_count:  0 concat_count:  3
# name wide_t1_073  wide_count: 0  narrow_count:  1 concat_count:  1
# name wide_t1_074  wide_count: 0  narrow_count:  4 concat_count:  4
# name wide_t1_075  wide_count: 0  narrow_count:  5 concat_count:  5
# name wide_t1_076  wide_count: 0  narrow_count:  5 concat_count:  5
# name wide_t1_077  wide_count: 0  narrow_count:  5 concat_count:  5
# name wide_t1_078  wide_count: 2  narrow_count:  5 concat_count:  5
# name wide_t1_079  wide_count: 2  narrow_count:  3 concat_count:  5
# name wide_t1_080  wide_count: 2  narrow_count:  4 concat_count:  6
# name wide_t1_081  wide_count: 7  narrow_count:  4 concat_count:  7
# name wide_t1_082  wide_count: 5  narrow_count:  1 concat_count:  5
# name wide_t1_083  wide_count: 3  narrow_count:  0 concat_count:  3
# name wide_t1_084  wide_count: 0  narrow_count:  2 concat_count:  2
# name wide_t1_085  wide_count: 0  narrow_count:  3 concat_count:  3
# name wide_t1_086  wide_count: 0  narrow_count:  3 concat_count:  3
# name wide_t1_087  wide_count: 0  narrow_count:  3 concat_count:  3
# name wide_t1_088  wide_count: 1  narrow_count:  4 concat_count:  4
# name wide_t1_089  wide_count: 1  narrow_count:  3 concat_count:  3
# name wide_t1_090  wide_count: 1  narrow_count:  3 concat_count:  3
# name wide_t1_091  wide_count: 3  narrow_count:  2 concat_count:  3
# name wide_t1_092  wide_count: 3  narrow_count:  2 concat_count:  3
# name wide_t1_093  wide_count: 2  narrow_count:  2 concat_count:  2
# name wide_t1_094  wide_count: 2  narrow_count:  2 concat_count:  2
# name wide_t1_095  wide_count: 2  narrow_count:  0 concat_count:  2
# name wide_t1_096  wide_count: 3  narrow_count:  0 concat_count:  3
# name wide_t1_097  wide_count: 3  narrow_count:  0 concat_count:  3
# name wide_t1_098  wide_count: 0  narrow_count:  2 concat_count:  2
# name wide_t1_099  wide_count: 0  narrow_count:  2 concat_count:  2
# name wide_t1_100  wide_count: 0  narrow_count:  2 concat_count:  2
# name wide_t1_101  wide_count: 0  narrow_count:  2 concat_count:  2
# name wide_t1_102  wide_count: 0  narrow_count:  2 concat_count:  2
# name wide_t1_103  wide_count: 0  narrow_count:  3 concat_count:  3
# name wide_t1_104  wide_count: 1  narrow_count:  1 concat_count:  2
# name wide_t1_105  wide_count: 2  narrow_count:  3 concat_count:  4
# name wide_t1_106  wide_count: 4  narrow_count:  2 concat_count:  5
# name wide_t1_107  wide_count: 2  narrow_count:  0 concat_count:  2
# name wide_t1_108  wide_count: 3  narrow_count:  0 concat_count:  3
# name wide_t1_109  wide_count: 0  narrow_count:  5 concat_count:  5
# name wide_t1_110  wide_count: 0  narrow_count:  4 concat_count:  4
# name wide_t1_111  wide_count: 0  narrow_count:  5 concat_count:  5
# name wide_t1_112  wide_count: 0  narrow_count:  5 concat_count:  5
# name wide_t1_113  wide_count: 0  narrow_count:  6 concat_count:  6
# name wide_t1_114  wide_count: 0  narrow_count:  8 concat_count:  8
# name wide_t1_115  wide_count: 3  narrow_count:  8 concat_count:  8
# name wide_t1_116  wide_count: 3  narrow_count:  8 concat_count:  8
# name wide_t1_117  wide_count: 3  narrow_count:  7 concat_count:  9
# name wide_t1_118  wide_count: 3  narrow_count:  6 concat_count:  8
# name wide_t1_119  wide_count: 6  narrow_count:  5 concat_count:  8
# name wide_t1_120  wide_count: 6  narrow_count:  6 concat_count:  9
# name wide_t1_121  wide_count: 4  narrow_count:  6 concat_count:  7
# name wide_t1_122  wide_count: 3  narrow_count:  6 concat_count:  6
# name wide_t1_123  wide_count: 3  narrow_count:  6 concat_count:  6
# name wide_t1_124  wide_count: 3  narrow_count:  6 concat_count:  6
# name wide_t1_125  wide_count: 3  narrow_count:  3 concat_count:  3
# name wide_t1_126  wide_count: 3  narrow_count:  5 concat_count:  5
# name wide_t1_127  wide_count: 3  narrow_count:  6 concat_count:  6
# name wide_t1_128  wide_count: 3  narrow_count:  5 concat_count:  5
# name wide_t1_129  wide_count: 3  narrow_count:  6 concat_count:  6
# name wide_t1_130  wide_count: 3  narrow_count:  5 concat_count:  5
# name wide_t1_131  wide_count: 3  narrow_count:  6 concat_count:  6
# name wide_t1_132  wide_count: 3  narrow_count:  5 concat_count:  5
# name wide_t1_133  wide_count: 3  narrow_count:  5 concat_count:  5
# name wide_t1_134  wide_count: 3  narrow_count:  2 concat_count:  5
# name wide_t1_135  wide_count: 3  narrow_count:  3 concat_count:  6
# name wide_t1_136  wide_count: 0  narrow_count:  4 concat_count:  4
# name wide_t1_137  wide_count: 0  narrow_count:  5 concat_count:  5
# name wide_t1_138  wide_count: 0  narrow_count:  5 concat_count:  5
# name wide_t1_139  wide_count: 0  narrow_count:  5 concat_count:  5
# name wide_t1_140  wide_count: 2  narrow_count:  5 concat_count:  5
# name wide_t1_141  wide_count: 2  narrow_count:  3 concat_count:  5
# name wide_t1_142  wide_count: 3  narrow_count:  3 concat_count:  3
# name wide_t1_143  wide_count: 3  narrow_count:  3 concat_count:  3
# name wide_t1_144  wide_count: 3  narrow_count:  1 concat_count:  4
# name wide_t1_145  wide_count: 0  narrow_count:  1 concat_count:  1
# name wide_t1_146  wide_count: 1  narrow_count:  1 concat_count:  1
# name wide_t1_147  wide_count: 0  narrow_count:  1 concat_count:  1
# name wide_t1_148  wide_count: 1  narrow_count:  1 concat_count:  1
# name wide_t1_149  wide_count: 0  narrow_count:  1 concat_count:  1
# name wide_t1_150  wide_count: 1  narrow_count:  1 concat_count:  1
# name wide_t1_151  wide_count: 1  narrow_count:  0 concat_count:  1
# name wide_t1_152  wide_count: 0  narrow_count:  1 concat_count:  1
# name wide_t1_153  wide_count: 1  narrow_count:  2 concat_count:  2
# name wide_t1_154  wide_count: 1  narrow_count:  3 concat_count:  3
# name wide_t1_155  wide_count: 4  narrow_count:  3 concat_count:  4
# name wide_t1_156  wide_count: 4  narrow_count:  2 concat_count:  3
# name wide_t1_157  wide_count: 3  narrow_count:  3 concat_count:  6
# name wide_t1_158  wide_count: 2  narrow_count:  3 concat_count:  3
# name wide_t1_159  wide_count: 2  narrow_count:  6 concat_count:  6
# name wide_t1_160  wide_count: 2  narrow_count:  4 concat_count:  6
# name wide_t1_161  wide_count: 2  narrow_count:  4 concat_count:  4
# name wide_t1_162  wide_count: 3  narrow_count:  4 concat_count:  5
# name wide_t1_163  wide_count: 3  narrow_count:  4 concat_count:  5
# name wide_t1_164  wide_count: 2  narrow_count:  3 concat_count:  5
# name wide_t1_165  wide_count: 0  narrow_count:  3 concat_count:  3
# name wide_t1_166  wide_count: 0  narrow_count:  3 concat_count:  3
# name wide_t1_167  wide_count: 1  narrow_count:  3 concat_count:  3
# name wide_t1_168  wide_count: 1  narrow_count:  3 concat_count:  3
# name wide_t1_169  wide_count: 1  narrow_count:  2 concat_count:  3
# name wide_t1_170  wide_count: 3  narrow_count:  2 concat_count:  3
# name wide_t1_171  wide_count: 2  narrow_count:  2 concat_count:  2
# name wide_t1_172  wide_count: 2  narrow_count:  2 concat_count:  2
# name wide_t1_173  wide_count: 2  narrow_count:  2 concat_count:  2
# name wide_t1_174  wide_count: 0  narrow_count:  2 concat_count:  2
# name wide_t1_175  wide_count: 0  narrow_count:  2 concat_count:  2
# name wide_t1_176  wide_count: 0  narrow_count:  2 concat_count:  2
# name wide_t1_177  wide_count: 0  narrow_count:  2 concat_count:  2
# name wide_t1_178  wide_count: 2  narrow_count:  2 concat_count:  2
# name wide_t1_179  wide_count: 2  narrow_count:  0 concat_count:  2
# name wide_t1_180  wide_count: 0  narrow_count:  3 concat_count:  3
# name wide_t1_181  wide_count: 0  narrow_count:  3 concat_count:  3
# name wide_t1_182  wide_count: 0  narrow_count:  3 concat_count:  3
# name wide_t1_183  wide_count: 0  narrow_count:  3 concat_count:  3
# name wide_t1_184  wide_count: 0  narrow_count:  2 concat_count:  2
# name wide_t1_185  wide_count: 0  narrow_count:  2 concat_count:  2
# name wide_t1_186  wide_count: 0  narrow_count:  2 concat_count:  2
# name wide_t1_187  wide_count: 0  narrow_count:  2 concat_count:  2
# name wide_t1_188  wide_count: 0  narrow_count:  2 concat_count:  2
# name wide_t1_189  wide_count: 0  narrow_count:  2 concat_count:  2
# name wide_t1_190  wide_count: 0  narrow_count:  2 concat_count:  2
# name wide_t1_191  wide_count: 0  narrow_count:  2 concat_count:  2
# name wide_t1_192  wide_count: 3  narrow_count:  1 concat_count:  3
# name wide_t1_193  wide_count: 3  narrow_count:  0 concat_count:  3
# name wide_t1_194  wide_count: 2  narrow_count:  0 concat_count:  2
# name wide_t1_195  wide_count: 0  narrow_count:  1 concat_count:  1
# name wide_t1_196  wide_count: 1  narrow_count:  1 concat_count:  1
# name wide_t1_197  wide_count: 1  narrow_count:  0 concat_count:  1
# name wide_t1_198  wide_count: 0  narrow_count:  1 concat_count:  1
# name wide_t1_199  wide_count: 0  narrow_count:  1 concat_count:  1
# name wide_t1_200  wide_count: 0  narrow_count:  1 concat_count:  1
# name wide_t1_201  wide_count: 0  narrow_count:  1 concat_count:  1
# name wide_t1_202  wide_count: 2  narrow_count:  2 concat_count:  3
# name wide_t1_203  wide_count: 2  narrow_count:  2 concat_count:  3
# name wide_t1_204  wide_count: 2  narrow_count:  3 concat_count:  4
# name wide_t1_205  wide_count: 1  narrow_count:  3 concat_count:  3
# name wide_t1_206  wide_count: 1  narrow_count:  1 concat_count:  2
# name wide_t1_207  wide_count: 1  narrow_count:  2 concat_count:  2
# name wide_t1_208  wide_count: 1  narrow_count:  2 concat_count:  2
# name wide_t1_209  wide_count: 3  narrow_count:  2 concat_count:  3
# name wide_t1_210  wide_count: 2  narrow_count:  2 concat_count:  2
# name wide_t1_211  wide_count: 2  narrow_count:  0 concat_count:  2
# name wide_t1_212  wide_count: 0  narrow_count:  3 concat_count:  3
# name wide_t1_213  wide_count: 0  narrow_count:  5 concat_count:  5
# name wide_t1_214  wide_count: 0  narrow_count:  3 concat_count:  3
# name wide_t1_215  wide_count: 0  narrow_count:  3 concat_count:  3
# name wide_t1_216  wide_count: 0  narrow_count:  3 concat_count:  3
# name wide_t1_217  wide_count: 0  narrow_count:  3 concat_count:  3
# name wide_t1_218  wide_count: 0  narrow_count:  4 concat_count:  4
# name wide_t1_219  wide_count: 0  narrow_count:  6 concat_count:  6
# name wide_t1_220  wide_count: 0  narrow_count:  6 concat_count:  6
# name wide_t1_221  wide_count: 0  narrow_count:  6 concat_count:  6
# name wide_t1_222  wide_count: 5  narrow_count:  6 concat_count:  6
# name wide_t1_223  wide_count: 5  narrow_count:  5 concat_count:  6
# name wide_t1_224  wide_count: 5  narrow_count:  5 concat_count:  5
# name wide_t1_225  wide_count: 5  narrow_count:  1 concat_count:  5
# name wide_t1_226  wide_count: 5  narrow_count:  1 concat_count:  5
# name wide_t1_227  wide_count: 0  narrow_count:  2 concat_count:  2
# name wide_t1_228  wide_count: 0  narrow_count:  2 concat_count:  2
# name wide_t1_229  wide_count: 0  narrow_count:  2 concat_count:  2
# name wide_t1_230  wide_count: 2  narrow_count:  2 concat_count:  2
# name wide_t1_231  wide_count: 2  narrow_count:  2 concat_count:  2
# name wide_t1_232  wide_count: 2  narrow_count:  2 concat_count:  2
# name wide_t1_233  wide_count: 2  narrow_count:  2 concat_count:  2
# name wide_t1_234  wide_count: 2  narrow_count:  2 concat_count:  2
# name wide_t1_235  wide_count: 2  narrow_count:  2 concat_count:  2
# name wide_t1_236  wide_count: 2  narrow_count:  2 concat_count:  2
# name wide_t1_237  wide_count: 2  narrow_count:  2 concat_count:  2
# name wide_t1_238  wide_count: 1  narrow_count:  2 concat_count:  3
# name wide_t1_239  wide_count: 2  narrow_count:  1 concat_count:  3
# name wide_t1_240  wide_count: 0  narrow_count:  1 concat_count:  1
# name wide_t1_241  wide_count: 1  narrow_count:  3 concat_count:  3
# name wide_t1_242  wide_count: 1  narrow_count:  3 concat_count:  3
# name wide_t1_243  wide_count: 1  narrow_count:  3 concat_count:  4
# name wide_t1_244  wide_count: 0  narrow_count:  2 concat_count:  2
# name wide_t1_245  wide_count: 0  narrow_count:  3 concat_count:  3
# name wide_t1_246  wide_count: 0  narrow_count:  2 concat_count:  2
# name wide_t1_247  wide_count: 0  narrow_count:  3 concat_count:  3
# name wide_t1_248  wide_count: 1  narrow_count:  2 concat_count:  2
# name wide_t1_249  wide_count: 3  narrow_count:  3 concat_count:  3
# name wide_t1_250  wide_count: 3  narrow_count:  1 concat_count:  3
# name wide_t1_251  wide_count: 1  narrow_count:  1 concat_count:  1
# name wide_t1_252  wide_count: 0  narrow_count:  4 concat_count:  4
# name wide_t1_253  wide_count: 0  narrow_count:  4 concat_count:  4
# name wide_t1_254  wide_count: 0  narrow_count:  4 concat_count:  4
# name wide_t1_255  wide_count: 1  narrow_count:  4 concat_count:  4
# name wide_t1_256  wide_count: 2  narrow_count:  4 concat_count:  4
# name wide_t1_257  wide_count: 2  narrow_count:  3 concat_count:  4
# name wide_t1_258  wide_count: 3  narrow_count:  2 concat_count:  5
# name wide_t1_259  wide_count: 1  narrow_count:  3 concat_count:  4
# name wide_t1_260  wide_count: 0  narrow_count:  3 concat_count:  3
# name wide_t1_261  wide_count: 1  narrow_count:  3 concat_count:  3
# name wide_t1_262  wide_count: 1  narrow_count:  3 concat_count:  3
# name wide_t1_263  wide_count: 0  narrow_count:  3 concat_count:  3
# name wide_t1_264  wide_count: 0  narrow_count:  3 concat_count:  3
# name wide_t1_265  wide_count: 0  narrow_count:  1 concat_count:  1
# name wide_t1_266  wide_count: 1  narrow_count:  2 concat_count:  2
# name wide_t1_267  wide_count: 1  narrow_count:  3 concat_count:  3
# name wide_t1_268  wide_count: 1  narrow_count:  3 concat_count:  3
# name wide_t1_269  wide_count: 1  narrow_count:  3 concat_count:  3
# name wide_t1_270  wide_count: 1  narrow_count:  3 concat_count:  3
# name wide_t1_271  wide_count: 2  narrow_count:  3 concat_count:  3
# name wide_t1_272  wide_count: 2  narrow_count:  3 concat_count:  3
# name wide_t1_273  wide_count: 2  narrow_count:  1 concat_count:  2
# name wide_t1_274  wide_count: 2  narrow_count:  0 concat_count:  2
# name wide_t1_275  wide_count: 2  narrow_count:  1 concat_count:  2
# name wide_t1_276  wide_count: 2  narrow_count:  1 concat_count:  2
# name wide_t1_277  wide_count: 0  narrow_count:  5 concat_count:  5
# name wide_t1_278  wide_count: 0  narrow_count:  5 concat_count:  5
# name wide_t1_279  wide_count: 0  narrow_count:  9 concat_count:  9
# name wide_t1_280  wide_count: 0  narrow_count:  10 concat_count:  10
# name wide_t1_281  wide_count: 5  narrow_count:  11 concat_count:  11
# name wide_t1_282  wide_count: 5  narrow_count:  12 concat_count:  12
# name wide_t1_283  wide_count: 6  narrow_count:  11 concat_count:  12
# name wide_t1_284  wide_count: 6  narrow_count:  6 concat_count:  12
# name wide_t1_285  wide_count: 6  narrow_count:  6 concat_count:  6
# name wide_t1_286  wide_count: 6  narrow_count:  6 concat_count:  6
# name wide_t1_287  wide_count: 6  narrow_count:  3 concat_count:  5
# name wide_t1_288  wide_count: 6  narrow_count:  0 concat_count:  6
# name wide_t1_289  wide_count: 0  narrow_count:  4 concat_count:  4
# name wide_t1_290  wide_count: 0  narrow_count:  4 concat_count:  4
# name wide_t1_291  wide_count: 0  narrow_count:  4 concat_count:  4
# name wide_t1_292  wide_count: 0  narrow_count:  4 concat_count:  4
# name wide_t1_293  wide_count: 4  narrow_count:  4 concat_count:  4
# name wide_t1_294  wide_count: 4  narrow_count:  4 concat_count:  4
# name wide_t1_295  wide_count: 4  narrow_count:  1 concat_count:  3
# name wide_t1_296  wide_count: 4  narrow_count:  0 concat_count:  4
# name wide_t1_297  wide_count: 0  narrow_count:  5 concat_count:  5
# name wide_t1_298  wide_count: 0  narrow_count:  6 concat_count:  6
# name wide_t1_299  wide_count: 0  narrow_count:  6 concat_count:  6
# name wide_t1_300  wide_count: 0  narrow_count:  6 concat_count:  6
# name wide_t1_301  wide_count: 0  narrow_count:  8 concat_count:  8
# name wide_t1_302  wide_count: 5  narrow_count:  8 concat_count:  8
# name wide_t1_303  wide_count: 5  narrow_count:  2 concat_count:  7
# name wide_t1_304  wide_count: 5  narrow_count:  3 concat_count:  8
# name wide_t1_305  wide_count: 0  narrow_count:  5 concat_count:  5
# name wide_t1_306  wide_count: 0  narrow_count:  5 concat_count:  5
# name wide_t1_307  wide_count: 0  narrow_count:  6 concat_count:  6
# name wide_t1_308  wide_count: 0  narrow_count:  5 concat_count:  5
# name wide_t1_309  wide_count: 0  narrow_count:  3 concat_count:  3
# name wide_t1_310  wide_count: 3  narrow_count:  6 concat_count:  6
# name wide_t1_311  wide_count: 3  narrow_count:  7 concat_count:  7
# name wide_t1_312  wide_count: 3  narrow_count:  6 concat_count:  7
# name wide_t1_313  wide_count: 2  narrow_count:  1 concat_count:  3
# name wide_t1_314  wide_count: 3  narrow_count:  1 concat_count:  3
# name wide_t1_315  wide_count: 4  narrow_count:  1 concat_count:  4
# name wide_t1_316  wide_count: 2  narrow_count:  0 concat_count:  2
# name wide_t1_317  wide_count: 0  narrow_count:  2 concat_count:  2
# name wide_t1_318  wide_count: 0  narrow_count:  2 concat_count:  2
# name wide_t1_319  wide_count: 0  narrow_count:  4 concat_count:  4
# name wide_t1_320  wide_count: 0  narrow_count:  3 concat_count:  3
# name wide_t1_321  wide_count: 0  narrow_count:  3 concat_count:  3
# name wide_t1_322  wide_count: 0  narrow_count:  2 concat_count:  2
# name wide_t1_323  wide_count: 0  narrow_count:  3 concat_count:  3
# name wide_t1_324  wide_count: 3  narrow_count:  4 concat_count:  4
# name wide_t1_325  wide_count: 3  narrow_count:  3 concat_count:  3
# name wide_t1_326  wide_count: 3  narrow_count:  3 concat_count:  3
# name wide_t1_327  wide_count: 3  narrow_count:  5 concat_count:  7
# name wide_t1_328  wide_count: 4  narrow_count:  3 concat_count:  5
# name wide_t1_329  wide_count: 6  narrow_count:  2 concat_count:  7
# name wide_t1_330  wide_count: 4  narrow_count:  2 concat_count:  5
# name wide_t1_331  wide_count: 4  narrow_count:  0 concat_count:  4
# name wide_t1_332  wide_count: 4  narrow_count:  0 concat_count:  4
# name wide_t1_333  wide_count: 0  narrow_count:  4 concat_count:  4
# name wide_t1_334  wide_count: 0  narrow_count:  4 concat_count:  4
# name wide_t1_335  wide_count: 2  narrow_count:  4 concat_count:  4

# %% [markdown]
# ### torch main

# %%
# homography_matrix = np.loadtxt(homography_matrix_file, usecols=range(3))
# dist_coff_narrow = np.loadtxt(narrow_cam_details_file, dtype=np.float32, skiprows=19,max_rows=1, delimiter=' ')
# camera_mtx_narrow = np.loadtxt(narrow_cam_details_file, dtype=np.float32, skiprows=14, max_rows=3, delimiter=' ')

# for (wide_cam_xml,narrow_cam_xml) in zip(wide_cam_files,narrow_cam_files):
#     file_data = get_xml_file_details(wide_cam_xml)
#     wide_bbox_data = get_bbox_data(wide_cam_xml)
#     narrow_bbox_data = get_bbox_data(narrow_cam_xml)
#     if (len(narrow_bbox_data)>0):
#         narrow_bbox_data[:,:4] = transform_narrow_bbox(narrow_bbox_data[:,:4],camera_mtx_narrow,dist_coff_narrow,homography_matrix)
#     # print("wide",wide_bbox_data.shape)
#     # print("narrow",narrow_bbox_data.shape)
#     wide_bbox_data = torch.from_numpy(wide_bbox_data)
#     narrow_bbox_data = torch.from_numpy(narrow_bbox_data)
#     concat_bbox_data = torch_concatenate_bboxes(narrow_bbox_data,wide_bbox_data,narrow_region)
#     concat_bbox_data = concat_bbox_data.cpu().detach().numpy()
#     output_file_prefix = narrow_cam_xml[-10:-4]
#     print("name",output_file_prefix," wide_count:",len(wide_bbox_data), " narrow_count: ",len(narrow_bbox_data), "concat_count: ",len(concat_bbox_data))
#     create_xml_file(DESTINATION_DIR=torch_output_xml_folder, file_prefix=output_file_prefix, width=1920, height=1080, voc_labels=concat_bbox_data,file_data=file_data)

#     # break
# Out:
# name t1_001  wide_count: 0  narrow_count:  3 concat_count:  3
# name t1_002  wide_count: 0  narrow_count:  3 concat_count:  3
# name t1_003  wide_count: 0  narrow_count:  3 concat_count:  3
# name t1_004  wide_count: 0  narrow_count:  4 concat_count:  4
# name t1_005  wide_count: 0  narrow_count:  4 concat_count:  4
# name t1_006  wide_count: 0  narrow_count:  4 concat_count:  4
# name t1_007  wide_count: 4  narrow_count:  0 concat_count:  4
# name t1_008  wide_count: 4  narrow_count:  0 concat_count:  4
# name t1_009  wide_count: 0  narrow_count:  4 concat_count:  4
# name t1_010  wide_count: 0  narrow_count:  4 concat_count:  4
# name t1_011  wide_count: 0  narrow_count:  4 concat_count:  4
# name t1_012  wide_count: 0  narrow_count:  4 concat_count:  4
# name t1_013  wide_count: 0  narrow_count:  4 concat_count:  4
# name t1_014  wide_count: 0  narrow_count:  4 concat_count:  4
# name t1_015  wide_count: 0  narrow_count:  4 concat_count:  4
# name t1_016  wide_count: 0  narrow_count:  4 concat_count:  4
# name t1_017  wide_count: 4  narrow_count:  4 concat_count:  4
# name t1_018  wide_count: 4  narrow_count:  4 concat_count:  4
# name t1_019  wide_count: 4  narrow_count:  6 concat_count:  10
# name t1_020  wide_count: 0  narrow_count:  6 concat_count:  6
# name t1_021  wide_count: 0  narrow_count:  6 concat_count:  6
# name t1_022  wide_count: 0  narrow_count:  3 concat_count:  3
# name t1_023  wide_count: 0  narrow_count:  4 concat_count:  4
# name t1_024  wide_count: 0  narrow_count:  6 concat_count:  6
# name t1_025  wide_count: 1  narrow_count:  6 concat_count:  6
# name t1_026  wide_count: 2  narrow_count:  6 concat_count:  6
# name t1_027  wide_count: 4  narrow_count:  6 concat_count:  6
# name t1_028  wide_count: 5  narrow_count:  6 concat_count:  6
# name t1_029  wide_count: 6  narrow_count:  4 concat_count:  6
# name t1_030  wide_count: 6  narrow_count:  4 concat_count:  6
# name t1_031  wide_count: 4  narrow_count:  0 concat_count:  4
# name t1_032  wide_count: 3  narrow_count:  1 concat_count:  3
# name t1_033  wide_count: 3  narrow_count:  3 concat_count:  3
# name t1_034  wide_count: 3  narrow_count:  3 concat_count:  3
# name t1_035  wide_count: 3  narrow_count:  3 concat_count:  3
# name t1_036  wide_count: 3  narrow_count:  2 concat_count:  3
# name t1_037  wide_count: 2  narrow_count:  0 concat_count:  2
# name t1_038  wide_count: 2  narrow_count:  0 concat_count:  2
# name t1_039  wide_count: 1  narrow_count:  4 concat_count:  4
# name t1_040  wide_count: 0  narrow_count:  4 concat_count:  4
# name t1_041  wide_count: 0  narrow_count:  4 concat_count:  4
# name t1_042  wide_count: 2  narrow_count:  3 concat_count:  3
# name t1_043  wide_count: 3  narrow_count:  4 concat_count:  4
# name t1_044  wide_count: 4  narrow_count:  0 concat_count:  4
# name t1_045  wide_count: 0  narrow_count:  1 concat_count:  1
# name t1_046  wide_count: 1  narrow_count:  1 concat_count:  1
# name t1_047  wide_count: 0  narrow_count:  5 concat_count:  5
# name t1_048  wide_count: 0  narrow_count:  5 concat_count:  5
# name t1_049  wide_count: 0  narrow_count:  5 concat_count:  5
# name t1_050  wide_count: 0  narrow_count:  6 concat_count:  6
# name t1_051  wide_count: 1  narrow_count:  6 concat_count:  6
# name t1_052  wide_count: 2  narrow_count:  6 concat_count:  6
# name t1_053  wide_count: 3  narrow_count:  5 concat_count:  6
# name t1_054  wide_count: 3  narrow_count:  3 concat_count:  6
# name t1_055  wide_count: 3  narrow_count:  3 concat_count:  5
# name t1_056  wide_count: 1  narrow_count:  3 concat_count:  3
# name t1_057  wide_count: 1  narrow_count:  3 concat_count:  3
# name t1_058  wide_count: 1  narrow_count:  3 concat_count:  3
# name t1_059  wide_count: 1  narrow_count:  3 concat_count:  3
# name t1_060  wide_count: 0  narrow_count:  3 concat_count:  3
# name t1_061  wide_count: 0  narrow_count:  3 concat_count:  3
# name t1_062  wide_count: 1  narrow_count:  3 concat_count:  3
# name t1_063  wide_count: 1  narrow_count:  3 concat_count:  3
# name t1_064  wide_count: 0  narrow_count:  3 concat_count:  3
# name t1_065  wide_count: 0  narrow_count:  3 concat_count:  3
# name t1_066  wide_count: 0  narrow_count:  3 concat_count:  3
# name t1_067  wide_count: 0  narrow_count:  3 concat_count:  3
# name t1_068  wide_count: 0  narrow_count:  3 concat_count:  3
# name t1_069  wide_count: 0  narrow_count:  3 concat_count:  3
# name t1_070  wide_count: 0  narrow_count:  3 concat_count:  3
# name t1_071  wide_count: 3  narrow_count:  0 concat_count:  3
# name t1_072  wide_count: 3  narrow_count:  0 concat_count:  3
# name t1_073  wide_count: 0  narrow_count:  1 concat_count:  1
# name t1_074  wide_count: 0  narrow_count:  4 concat_count:  4
# name t1_075  wide_count: 0  narrow_count:  5 concat_count:  5
# name t1_076  wide_count: 0  narrow_count:  5 concat_count:  5
# name t1_077  wide_count: 0  narrow_count:  5 concat_count:  5
# name t1_078  wide_count: 2  narrow_count:  5 concat_count:  5
# name t1_079  wide_count: 2  narrow_count:  3 concat_count:  5
# name t1_080  wide_count: 2  narrow_count:  4 concat_count:  6
# name t1_081  wide_count: 7  narrow_count:  4 concat_count:  7
# name t1_082  wide_count: 5  narrow_count:  1 concat_count:  5
# name t1_083  wide_count: 3  narrow_count:  0 concat_count:  3
# name t1_084  wide_count: 0  narrow_count:  2 concat_count:  2
# name t1_085  wide_count: 0  narrow_count:  3 concat_count:  3
# name t1_086  wide_count: 0  narrow_count:  3 concat_count:  3
# name t1_087  wide_count: 1  narrow_count:  3 concat_count:  3
# name t1_088  wide_count: 1  narrow_count:  4 concat_count:  4
# name t1_089  wide_count: 1  narrow_count:  3 concat_count:  3
# name t1_090  wide_count: 2  narrow_count:  3 concat_count:  3
# name t1_091  wide_count: 3  narrow_count:  2 concat_count:  3
# name t1_092  wide_count: 3  narrow_count:  2 concat_count:  3
# name t1_093  wide_count: 2  narrow_count:  2 concat_count:  2
# name t1_094  wide_count: 2  narrow_count:  2 concat_count:  2
# name t1_095  wide_count: 2  narrow_count:  0 concat_count:  2
# name t1_096  wide_count: 3  narrow_count:  0 concat_count:  3
# name t1_097  wide_count: 3  narrow_count:  0 concat_count:  3
# name t1_098  wide_count: 0  narrow_count:  2 concat_count:  2
# name t1_099  wide_count: 0  narrow_count:  2 concat_count:  2
# name t1_100  wide_count: 0  narrow_count:  2 concat_count:  2
# name t1_101  wide_count: 0  narrow_count:  2 concat_count:  2
# name t1_102  wide_count: 0  narrow_count:  2 concat_count:  2
# name t1_103  wide_count: 0  narrow_count:  3 concat_count:  3
# name t1_104  wide_count: 1  narrow_count:  1 concat_count:  2
# name t1_105  wide_count: 2  narrow_count:  3 concat_count:  4
# name t1_106  wide_count: 4  narrow_count:  2 concat_count:  5
# name t1_107  wide_count: 2  narrow_count:  0 concat_count:  2
# name t1_108  wide_count: 3  narrow_count:  0 concat_count:  3
# name t1_109  wide_count: 0  narrow_count:  5 concat_count:  5
# name t1_110  wide_count: 0  narrow_count:  4 concat_count:  4
# name t1_111  wide_count: 0  narrow_count:  7 concat_count:  7
# name t1_112  wide_count: 0  narrow_count:  7 concat_count:  7
# name t1_113  wide_count: 0  narrow_count:  7 concat_count:  7
# name t1_114  wide_count: 0  narrow_count:  9 concat_count:  9
# name t1_115  wide_count: 3  narrow_count:  9 concat_count:  9
# name t1_116  wide_count: 3  narrow_count:  9 concat_count:  9
# name t1_117  wide_count: 3  narrow_count:  7 concat_count:  7
# name t1_118  wide_count: 3  narrow_count:  7 concat_count:  9
# name t1_119  wide_count: 6  narrow_count:  6 concat_count:  9
# name t1_120  wide_count: 6  narrow_count:  6 concat_count:  9
# name t1_121  wide_count: 4  narrow_count:  6 concat_count:  7
# name t1_122  wide_count: 3  narrow_count:  6 concat_count:  6
# name t1_123  wide_count: 3  narrow_count:  6 concat_count:  6
# name t1_124  wide_count: 3  narrow_count:  6 concat_count:  6
# name t1_125  wide_count: 3  narrow_count:  3 concat_count:  3
# name t1_126  wide_count: 3  narrow_count:  5 concat_count:  5
# name t1_127  wide_count: 3  narrow_count:  6 concat_count:  6
# name t1_128  wide_count: 3  narrow_count:  6 concat_count:  6
# name t1_129  wide_count: 3  narrow_count:  6 concat_count:  6
# name t1_130  wide_count: 3  narrow_count:  6 concat_count:  6
# name t1_131  wide_count: 3  narrow_count:  6 concat_count:  6
# name t1_132  wide_count: 3  narrow_count:  6 concat_count:  6
# name t1_133  wide_count: 3  narrow_count:  5 concat_count:  5
# name t1_134  wide_count: 3  narrow_count:  3 concat_count:  6
# name t1_135  wide_count: 3  narrow_count:  3 concat_count:  6
# name t1_136  wide_count: 0  narrow_count:  4 concat_count:  4
# name t1_137  wide_count: 0  narrow_count:  5 concat_count:  5
# name t1_138  wide_count: 0  narrow_count:  5 concat_count:  5
# name t1_139  wide_count: 0  narrow_count:  5 concat_count:  5
# name t1_140  wide_count: 2  narrow_count:  5 concat_count:  5
# name t1_141  wide_count: 2  narrow_count:  3 concat_count:  5
# name t1_142  wide_count: 3  narrow_count:  3 concat_count:  3
# name t1_143  wide_count: 3  narrow_count:  3 concat_count:  3
# name t1_144  wide_count: 3  narrow_count:  1 concat_count:  4
# name t1_145  wide_count: 0  narrow_count:  1 concat_count:  1
# name t1_146  wide_count: 1  narrow_count:  1 concat_count:  1
# name t1_147  wide_count: 0  narrow_count:  1 concat_count:  1
# name t1_148  wide_count: 1  narrow_count:  1 concat_count:  1
# name t1_149  wide_count: 0  narrow_count:  1 concat_count:  1
# name t1_150  wide_count: 1  narrow_count:  1 concat_count:  1
# name t1_151  wide_count: 1  narrow_count:  0 concat_count:  1
# name t1_152  wide_count: 0  narrow_count:  1 concat_count:  1
# name t1_153  wide_count: 1  narrow_count:  2 concat_count:  2
# name t1_154  wide_count: 1  narrow_count:  3 concat_count:  3
# name t1_155  wide_count: 4  narrow_count:  3 concat_count:  3
# name t1_156  wide_count: 4  narrow_count:  2 concat_count:  4
# name t1_157  wide_count: 3  narrow_count:  3 concat_count:  6
# name t1_158  wide_count: 2  narrow_count:  3 concat_count:  3
# name t1_159  wide_count: 2  narrow_count:  6 concat_count:  6
# name t1_160  wide_count: 2  narrow_count:  4 concat_count:  6
# name t1_161  wide_count: 2  narrow_count:  4 concat_count:  4
# name t1_162  wide_count: 3  narrow_count:  4 concat_count:  5
# name t1_163  wide_count: 3  narrow_count:  4 concat_count:  5
# name t1_164  wide_count: 2  narrow_count:  3 concat_count:  5
# name t1_165  wide_count: 0  narrow_count:  3 concat_count:  3
# name t1_166  wide_count: 0  narrow_count:  3 concat_count:  3
# name t1_167  wide_count: 1  narrow_count:  3 concat_count:  3
# name t1_168  wide_count: 1  narrow_count:  3 concat_count:  3
# name t1_169  wide_count: 1  narrow_count:  2 concat_count:  3
# name t1_170  wide_count: 3  narrow_count:  2 concat_count:  3
# name t1_171  wide_count: 2  narrow_count:  2 concat_count:  2
# name t1_172  wide_count: 2  narrow_count:  2 concat_count:  2
# name t1_173  wide_count: 2  narrow_count:  2 concat_count:  2
# name t1_174  wide_count: 0  narrow_count:  2 concat_count:  2
# name t1_175  wide_count: 0  narrow_count:  2 concat_count:  2
# name t1_176  wide_count: 0  narrow_count:  2 concat_count:  2
# name t1_177  wide_count: 0  narrow_count:  2 concat_count:  2
# name t1_178  wide_count: 2  narrow_count:  2 concat_count:  2
# name t1_179  wide_count: 2  narrow_count:  0 concat_count:  2
# name t1_180  wide_count: 0  narrow_count:  3 concat_count:  3
# name t1_181  wide_count: 0  narrow_count:  3 concat_count:  3
# name t1_182  wide_count: 0  narrow_count:  3 concat_count:  3
# name t1_183  wide_count: 0  narrow_count:  3 concat_count:  3
# name t1_184  wide_count: 0  narrow_count:  2 concat_count:  2
# name t1_185  wide_count: 0  narrow_count:  2 concat_count:  2
# name t1_186  wide_count: 0  narrow_count:  2 concat_count:  2
# name t1_187  wide_count: 0  narrow_count:  2 concat_count:  2
# name t1_188  wide_count: 0  narrow_count:  2 concat_count:  2
# name t1_189  wide_count: 0  narrow_count:  2 concat_count:  2
# name t1_190  wide_count: 0  narrow_count:  2 concat_count:  2
# name t1_191  wide_count: 0  narrow_count:  2 concat_count:  2
# name t1_192  wide_count: 3  narrow_count:  1 concat_count:  3
# name t1_193  wide_count: 3  narrow_count:  0 concat_count:  3
# name t1_194  wide_count: 2  narrow_count:  0 concat_count:  2
# name t1_195  wide_count: 0  narrow_count:  1 concat_count:  1
# name t1_196  wide_count: 1  narrow_count:  1 concat_count:  1
# name t1_197  wide_count: 1  narrow_count:  0 concat_count:  1
# name t1_198  wide_count: 0  narrow_count:  1 concat_count:  1
# name t1_199  wide_count: 0  narrow_count:  1 concat_count:  1
# name t1_200  wide_count: 0  narrow_count:  1 concat_count:  1
# name t1_201  wide_count: 0  narrow_count:  1 concat_count:  1
# name t1_202  wide_count: 2  narrow_count:  2 concat_count:  3
# name t1_203  wide_count: 2  narrow_count:  2 concat_count:  3
# name t1_204  wide_count: 2  narrow_count:  3 concat_count:  4
# name t1_205  wide_count: 2  narrow_count:  3 concat_count:  3
# name t1_206  wide_count: 2  narrow_count:  1 concat_count:  2
# name t1_207  wide_count: 1  narrow_count:  2 concat_count:  2
# name t1_208  wide_count: 1  narrow_count:  2 concat_count:  2
# name t1_209  wide_count: 3  narrow_count:  2 concat_count:  3
# name t1_210  wide_count: 2  narrow_count:  2 concat_count:  2
# name t1_211  wide_count: 2  narrow_count:  0 concat_count:  2
# name t1_212  wide_count: 0  narrow_count:  3 concat_count:  3
# name t1_213  wide_count: 0  narrow_count:  5 concat_count:  5
# name t1_214  wide_count: 0  narrow_count:  3 concat_count:  3
# name t1_215  wide_count: 0  narrow_count:  3 concat_count:  3
# name t1_216  wide_count: 0  narrow_count:  3 concat_count:  3
# name t1_217  wide_count: 0  narrow_count:  3 concat_count:  3
# name t1_218  wide_count: 0  narrow_count:  4 concat_count:  4
# name t1_219  wide_count: 0  narrow_count:  6 concat_count:  6
# name t1_220  wide_count: 0  narrow_count:  6 concat_count:  6
# name t1_221  wide_count: 0  narrow_count:  6 concat_count:  6
# name t1_222  wide_count: 5  narrow_count:  6 concat_count:  6
# name t1_223  wide_count: 5  narrow_count:  5 concat_count:  6
# name t1_224  wide_count: 5  narrow_count:  5 concat_count:  5
# name t1_225  wide_count: 5  narrow_count:  1 concat_count:  5
# name t1_226  wide_count: 5  narrow_count:  1 concat_count:  5
# name t1_227  wide_count: 0  narrow_count:  2 concat_count:  2
# name t1_228  wide_count: 0  narrow_count:  2 concat_count:  2
# name t1_229  wide_count: 0  narrow_count:  2 concat_count:  2
# name t1_230  wide_count: 2  narrow_count:  2 concat_count:  2
# name t1_231  wide_count: 2  narrow_count:  2 concat_count:  2
# name t1_232  wide_count: 2  narrow_count:  2 concat_count:  2
# name t1_233  wide_count: 2  narrow_count:  2 concat_count:  2
# name t1_234  wide_count: 2  narrow_count:  2 concat_count:  2
# name t1_235  wide_count: 2  narrow_count:  2 concat_count:  2
# name t1_236  wide_count: 2  narrow_count:  2 concat_count:  2
# name t1_237  wide_count: 2  narrow_count:  2 concat_count:  2
# name t1_238  wide_count: 1  narrow_count:  2 concat_count:  3
# name t1_239  wide_count: 2  narrow_count:  1 concat_count:  3
# name t1_240  wide_count: 0  narrow_count:  1 concat_count:  1
# name t1_241  wide_count: 1  narrow_count:  3 concat_count:  3
# name t1_242  wide_count: 1  narrow_count:  3 concat_count:  3
# name t1_243  wide_count: 1  narrow_count:  3 concat_count:  4
# name t1_244  wide_count: 0  narrow_count:  2 concat_count:  2
# name t1_245  wide_count: 0  narrow_count:  3 concat_count:  3
# name t1_246  wide_count: 0  narrow_count:  2 concat_count:  2
# name t1_247  wide_count: 0  narrow_count:  3 concat_count:  3
# name t1_248  wide_count: 1  narrow_count:  2 concat_count:  2
# name t1_249  wide_count: 3  narrow_count:  3 concat_count:  3
# name t1_250  wide_count: 3  narrow_count:  1 concat_count:  3
# name t1_251  wide_count: 1  narrow_count:  1 concat_count:  1
# name t1_252  wide_count: 0  narrow_count:  4 concat_count:  4
# name t1_253  wide_count: 0  narrow_count:  4 concat_count:  4
# name t1_254  wide_count: 0  narrow_count:  4 concat_count:  4
# name t1_255  wide_count: 1  narrow_count:  4 concat_count:  4
# name t1_256  wide_count: 2  narrow_count:  4 concat_count:  4
# name t1_257  wide_count: 2  narrow_count:  3 concat_count:  4
# name t1_258  wide_count: 3  narrow_count:  2 concat_count:  5
# name t1_259  wide_count: 1  narrow_count:  3 concat_count:  4
# name t1_260  wide_count: 0  narrow_count:  3 concat_count:  3
# name t1_261  wide_count: 1  narrow_count:  3 concat_count:  3
# name t1_262  wide_count: 1  narrow_count:  3 concat_count:  3
# name t1_263  wide_count: 0  narrow_count:  3 concat_count:  3
# name t1_264  wide_count: 1  narrow_count:  3 concat_count:  3
# name t1_265  wide_count: 0  narrow_count:  1 concat_count:  1
# name t1_266  wide_count: 1  narrow_count:  2 concat_count:  2
# name t1_267  wide_count: 1  narrow_count:  3 concat_count:  3
# name t1_268  wide_count: 1  narrow_count:  3 concat_count:  3
# name t1_269  wide_count: 1  narrow_count:  3 concat_count:  3
# name t1_270  wide_count: 1  narrow_count:  3 concat_count:  3
# name t1_271  wide_count: 2  narrow_count:  3 concat_count:  3
# name t1_272  wide_count: 2  narrow_count:  3 concat_count:  3
# name t1_273  wide_count: 2  narrow_count:  1 concat_count:  2
# name t1_274  wide_count: 2  narrow_count:  0 concat_count:  2
# name t1_275  wide_count: 2  narrow_count:  1 concat_count:  2
# name t1_276  wide_count: 2  narrow_count:  1 concat_count:  2
# name t1_277  wide_count: 0  narrow_count:  5 concat_count:  5
# name t1_278  wide_count: 0  narrow_count:  5 concat_count:  5
# name t1_279  wide_count: 0  narrow_count:  9 concat_count:  9
# name t1_280  wide_count: 0  narrow_count:  10 concat_count:  10
# name t1_281  wide_count: 5  narrow_count:  11 concat_count:  11
# name t1_282  wide_count: 5  narrow_count:  12 concat_count:  12
# name t1_283  wide_count: 6  narrow_count:  11 concat_count:  12
# name t1_284  wide_count: 6  narrow_count:  6 concat_count:  12
# name t1_285  wide_count: 6  narrow_count:  6 concat_count:  6
# name t1_286  wide_count: 6  narrow_count:  6 concat_count:  6
# name t1_287  wide_count: 6  narrow_count:  3 concat_count:  4
# name t1_288  wide_count: 6  narrow_count:  0 concat_count:  6
# name t1_289  wide_count: 0  narrow_count:  4 concat_count:  4
# name t1_290  wide_count: 0  narrow_count:  4 concat_count:  4
# name t1_291  wide_count: 0  narrow_count:  4 concat_count:  4
# name t1_292  wide_count: 0  narrow_count:  4 concat_count:  4
# name t1_293  wide_count: 4  narrow_count:  4 concat_count:  4
# name t1_294  wide_count: 4  narrow_count:  4 concat_count:  4
# name t1_295  wide_count: 4  narrow_count:  1 concat_count:  1
# name t1_296  wide_count: 4  narrow_count:  0 concat_count:  4
# name t1_297  wide_count: 0  narrow_count:  5 concat_count:  5
# name t1_298  wide_count: 0  narrow_count:  11 concat_count:  11
# name t1_299  wide_count: 0  narrow_count:  11 concat_count:  11
# name t1_300  wide_count: 0  narrow_count:  11 concat_count:  11
# name t1_301  wide_count: 0  narrow_count:  10 concat_count:  10
# name t1_302  wide_count: 5  narrow_count:  10 concat_count:  10
# name t1_303  wide_count: 5  narrow_count:  5 concat_count:  9
# name t1_304  wide_count: 5  narrow_count:  5 concat_count:  10
# name t1_305  wide_count: 0  narrow_count:  5 concat_count:  5
# name t1_306  wide_count: 0  narrow_count:  5 concat_count:  5
# name t1_307  wide_count: 0  narrow_count:  6 concat_count:  6
# name t1_308  wide_count: 0  narrow_count:  5 concat_count:  5
# name t1_309  wide_count: 0  narrow_count:  3 concat_count:  3
# name t1_310  wide_count: 3  narrow_count:  6 concat_count:  6
# name t1_311  wide_count: 3  narrow_count:  7 concat_count:  7
# name t1_312  wide_count: 3  narrow_count:  6 concat_count:  7
# name t1_313  wide_count: 2  narrow_count:  1 concat_count:  3
# name t1_314  wide_count: 3  narrow_count:  1 concat_count:  3
# name t1_315  wide_count: 4  narrow_count:  1 concat_count:  4
# name t1_316  wide_count: 2  narrow_count:  0 concat_count:  2
# name t1_317  wide_count: 0  narrow_count:  2 concat_count:  2
# name t1_318  wide_count: 0  narrow_count:  2 concat_count:  2
# name t1_319  wide_count: 0  narrow_count:  4 concat_count:  4
# name t1_320  wide_count: 0  narrow_count:  3 concat_count:  3
# name t1_321  wide_count: 0  narrow_count:  3 concat_count:  3
# name t1_322  wide_count: 0  narrow_count:  2 concat_count:  2
# name t1_323  wide_count: 0  narrow_count:  3 concat_count:  3
# name t1_324  wide_count: 3  narrow_count:  4 concat_count:  4
# name t1_325  wide_count: 3  narrow_count:  3 concat_count:  3
# name t1_326  wide_count: 3  narrow_count:  3 concat_count:  3
# name t1_327  wide_count: 3  narrow_count:  5 concat_count:  7
# name t1_328  wide_count: 5  narrow_count:  3 concat_count:  6
# name t1_329  wide_count: 6  narrow_count:  2 concat_count:  7
# name t1_330  wide_count: 4  narrow_count:  2 concat_count:  5
# name t1_331  wide_count: 4  narrow_count:  0 concat_count:  4
# name t1_332  wide_count: 4  narrow_count:  0 concat_count:  4
# name t1_333  wide_count: 0  narrow_count:  4 concat_count:  4
# name t1_334  wide_count: 2  narrow_count:  4 concat_count:  4
# name t1_335  wide_count: 4  narrow_count:  4 concat_count:  4
