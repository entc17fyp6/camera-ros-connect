# %%
import pypylon.pylon as py
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
tlf = py.TlFactory.GetInstance()

# %%
tlf
# Out:
# <pypylon.pylon.TlFactory; proxy of <Swig Object of type 'Pylon::CTlFactory *' at 0x7f40d952f720> >

# %%
devices = tlf.EnumerateDevices()

# %%
print (len(devices))
# Out:
# 1

# %%
for d in devices:
    print(d.GetModelName(), d.GetSerialNumber(), d.GetFriendlyName(), d.GetUserDefinedName())
# Out:
# daA1920-30uc 23841227 Narrow (23841227) Narrow

# %%
cam = py.InstantCamera(tlf.CreateDevice(devices[0]))

# %%
cam = py.InstantCamera(tlf.CreateFirstDevice())

# %%
cam.Open()

# %%
cam.Gain.Value
cam.ExposureTime.Value
# Out:
# 38215.0

# %%
cam.Gain.SetValue(12.1)

# %%
cam.TriggerSelector.Value
# Out:
# 'FrameStart'

# %%
cam.UserSetSelector = 'Default'
cam.UserSetLoad.Execute()

# %%
cam.PixelFormat.Symbolics
# Out:
# ('RGB8', 'YCbCr422_8', 'BayerGB8', 'BayerGB12')

# %%
cam.PixelFormat.GetValue()
# Out:
# 'YCbCr422_8'

# %%
# cam.PixelFormat = "YCbCr422_8"
cam.PixelFormat = 'RGB8'

# %%
res = cam.GrabOne(1000)

# %%
res.GetBuffer()[:100]
# Out:
# bytearray(b'\x1b\x1c\x14\x1c\x19\x16\x1b\x14\x19\x1b\x12\x1b\x1a\x0e\x1d\x18\x12\x1d\x18\x15\x1c\x18\x14\x1e\x1a\x12\x1f\x1c\x12\x1f\x19\x12 \x15\x13\x1f\x15\x15\x1e\x11\x10\x1d\x15\x16 \x13\x15!\x0f\x14"\x0b\x13"\x0c\x11"\x10\x12\x1f\x0f\x16\x1b\x0e\x16\x1c\x13\x16\x1c\x17\x12\x1f\x1c\x11!\x1c\x10\x1c\x1e\x17\x1e\x19\x16\x1b\x18\x16\x19\x18\x12\x1b\x15\x11\x1e\x13\x13\x1e\x11\x14\x1e\x0e')

# %%
img = res.GetArray()

# %%
img.shape
print(type(img[0][0][0]))
# Out:
# <class 'numpy.uint8'>

# %%
plt.imshow(img)
cv2.imshow("aa",img)
cv2.waitKey(0)
# Out:
# -1

# %%
converter = py.ImageFormatConverter()
converter.OutputPixelFormat = py.PixelType_RGB8packed
converter.OutputBitAlignment = "MsbAligned"

# %%
cam.PixelFormat = 'YCbCr422_8'
img = cam.GrabOne(1000)
img = converter.Convert(img)
frame = img.GetArray()
print(type(frame[0][0][0]))
plt.imshow(frame)
cv2.imshow("aa",frame)
cv2.waitKey(0)
# Out:
# Error: Session cannot generate requests
# at w.executeCodeCell (/home/samare/.vscode/extensions/ms-toolsai.jupyter-2021.8.1236758218/out/client/extension.js:90:327199)
# at w.execute (/home/samare/.vscode/extensions/ms-toolsai.jupyter-2021.8.1236758218/out/client/extension.js:90:326520)
# at w.start (/home/samare/.vscode/extensions/ms-toolsai.jupyter-2021.8.1236758218/out/client/extension.js:90:322336)
# at runMicrotasks (<anonymous>)
# at processTicksAndRejections (internal/process/task_queues.js:93:5)
# at async t.CellExecutionQueue.executeQueuedCells (/home/samare/.vscode/extensions/ms-toolsai.jupyter-2021.8.1236758218/out/client/extension.js:90:336863)
# at async t.CellExecutionQueue.start (/home/samare/.vscode/extensions/ms-toolsai.jupyter-2021.8.1236758218/out/client/extension.js:90:336403)

# %%
cam.PixelFormat.Value
# Out:
# 'YCbCr422_8'

# %%
plt.plot(img[:,1000])
# Out:
# [<matplotlib.lines.Line2D at 0xf037250>,
#  <matplotlib.lines.Line2D at 0xf037268>,
#  <matplotlib.lines.Line2D at 0xf0372f8>]

# %%
cam.Close()

# %%
cam.IsGrabbing()
# Out:
# Error: Session cannot generate requests
# at w.executeCodeCell (/home/samare/.vscode/extensions/ms-toolsai.jupyter-2021.8.1236758218/out/client/extension.js:90:327199)
# at w.execute (/home/samare/.vscode/extensions/ms-toolsai.jupyter-2021.8.1236758218/out/client/extension.js:90:326520)
# at w.start (/home/samare/.vscode/extensions/ms-toolsai.jupyter-2021.8.1236758218/out/client/extension.js:90:322336)
# at runMicrotasks (<anonymous>)
# at processTicksAndRejections (internal/process/task_queues.js:93:5)
# at async t.CellExecutionQueue.executeQueuedCells (/home/samare/.vscode/extensions/ms-toolsai.jupyter-2021.8.1236758218/out/client/extension.js:90:336863)
# at async t.CellExecutionQueue.start (/home/samare/.vscode/extensions/ms-toolsai.jupyter-2021.8.1236758218/out/client/extension.js:90:336403)
